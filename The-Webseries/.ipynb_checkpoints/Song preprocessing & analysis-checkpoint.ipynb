# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('Billboard-Weekly-Songs-With-Song-And-Artist-Spotify-Popularity.csv')
data2=pd.read_csv('Billboard-Yearly-Chart-With-Spotify-Popularity-Of-Song-And-Artist.csv')
data3=pd.read_csv('Hollywood-Music-WCBS-Ranking.csv')

# %%
data.head(5)
data.shape
data
# Out:
#               date  Rank              Title  \
# 0       1955-01-01     1   Poor Little Fool
# 1       1955-01-01     2           Patricia
# 2       1955-01-01     3      Splish Splash
# 3       1955-01-01     4  Hard Headed Woman
# 4       1955-01-01     5               When
# ...            ...   ...                ...
# 300595  2017-12-22    96          Faking It
# 300596  2017-12-22    97           Marry Me
# 300597  2017-12-22    98  Five More Minutes
# 300598  2017-12-22    99           Criminal
# 300599  2017-12-22   100        Sauce It Up
#
#                                               Artist  Weeks on chart  year  \
# 0                                       Ricky Nelson             1.0  1955
# 1                      Perez Prado And His Orchestra             NaN  1955
# 2                                        Bobby Darin             NaN  1955
# 3                 Elvis Presley With The Jordanaires             NaN  1955
# 4                                        Kalin Twins             NaN  1955
# ...                                              ...             ...   ...
# 300595  Calvin Harris Featuring Kehlani & Lil Yachty             3.0  2017
# 300596                                  Thomas Rhett            15.0  2017
# 300597                               Scotty McCreery            15.0  2017
# 300598                         Natti Natasha x Ozuna            15.0  2017
# 300599                                  Lil Uzi Vert            15.0  2017
#
#         Spotify_Popularity  Artist_Popularity
# 0                       -1                 56
# 1                       -1                 12
# 2                       -1                 62
# 3                       -1                 -1
# 4                       -1                 24
# ...                    ...                ...
# 300595                  -1                 -1
# 300596                  75                 78
# 300597                  65                 66
# 300598                  -1                 -1
# 300599                  74                 89
#
# [300600 rows x 8 columns]

# %%
data2.head(5)
data2.shape
data2
data3.head(5)
data3.shape
data3
# Out:
#       Unnamed: 0  Rank  Year                  Artist  \
# 0              0     1  1956         The Five Satins
# 1              1     2  1954            The Penguins
# 2              2     3  1961           Elvis Presley
# 3              3     4  1965  The Righteous Brothers
# 4              4     5  1957             Mello-Kings
# ...          ...   ...   ...                     ...
# 7985         993   495  1962            The Exciters
# 7986         994   496  1968            The Box Tops
# 7987         995   497  1965             The Beatles
# 7988         996   498  1970         George Harrison
# 7989         997   499  1967       The 5th Dimension
#
#                            Song1  Chart_Year
# 0       In The Still Of The Nite        1995
# 1                   Hey Senorita        1995
# 2     Can't Help Falling In Love        1995
# 3                    Hung On You        1995
# 4                 Tonite, Tonite        1995
# ...                          ...         ...
# 7985              Hard Way To Go        1973
# 7986   The Door You Closed To Me        1973
# 7987                    I'm Down        1973
# 7988             Isn't It A Pity        1973
# 7989        Which Way To Nowhere        1973
#
# [7990 rows x 6 columns]

# %%
data2
# Out:
#       year  Rank           Artist                         Title  \
# 0     1960     1      Percy Faith   Theme From “A Summer Place”
# 1     1960     2       Jim Reeves              He’ll Have To Go
# 2     1960     3  Everly Brothers                 Cathy’s Clown
# 3     1960     4   Johnny Preston                  Running Bear
# 4     1960     5     Mark Dinning                    Teen Angel
# ...    ...   ...              ...                           ...
# 5295  2012    96        Kip Moore       Somethin’ ‘Bout A Truck
# 5296  2012    97           Miguel                         Adorn
# 5297  2012    98     Jason Aldean               Fly Over States
# 5298  2012    99   Eli Young Band  Even If It Breaks Your Heart
# 5299  2012   100      Linkin Park                  Burn It Down
#
#       Spotify_Popularity  Artist_Popularity
# 0                     52                 52
# 1                     -1                 60
# 2                     -1                 62
# 3                     -1                 34
# 4                     -1                 22
# ...                  ...                ...
# 5295                  65                 68
# 5296                  64                 84
# 5297                  61                 78
# 5298                  66                 65
# 5299                  71                 86
#
# [5300 rows x 6 columns]

# %%
data = data2.loc[:,['Title','Artist','Spotify_Popularity','Artist_Popularity','year']]

# %%
data
# Out:
#                              Title           Artist  Spotify_Popularity  \
# 0      Theme From “A Summer Place”      Percy Faith                  52
# 1                 He’ll Have To Go       Jim Reeves                  -1
# 2                    Cathy’s Clown  Everly Brothers                  -1
# 3                     Running Bear   Johnny Preston                  -1
# 4                       Teen Angel     Mark Dinning                  -1
# ...                            ...              ...                 ...
# 5295       Somethin’ ‘Bout A Truck        Kip Moore                  65
# 5296                         Adorn           Miguel                  64
# 5297               Fly Over States     Jason Aldean                  61
# 5298  Even If It Breaks Your Heart   Eli Young Band                  66
# 5299                  Burn It Down      Linkin Park                  71
#
#       Artist_Popularity  year
# 0                    52  1960
# 1                    60  1960
# 2                    62  1960
# 3                    34  1960
# 4                    22  1960
# ...                 ...   ...
# 5295                 68  2012
# 5296                 84  2012
# 5297                 78  2012
# 5298                 65  2012
# 5299                 86  2012
#
# [5300 rows x 5 columns]

# %%
data['Title'] = data['Title'].replace(np.nan, 'unknown')
data['Artist'] = data['Artist'].replace(np.nan, 'unknown')

# %%
data['Title'] = data['Title'].str.lower()
data["Title"]
data.loc[data["Artist"]=='Linkin Park',['Title','Artist','Spotify_Popularity','Artist_Popularity','year']]
# data.to_csv('main_song.csv',index=False)
# Out:
#                    Title       Artist  Spotify_Popularity  Artist_Popularity  \
# 4206          in the end  Linkin Park                  83                 86
# 4432                numb  Linkin Park                  81                 86
# 4478  breaking the habit  Linkin Park                  64                 86
# 4737      what i’ve done  Linkin Park                  -1                 86
# 4854   shadow of the day  Linkin Park                  66                 86
# 4960          new divide  Linkin Park                  67                 86
# 5299        burn it down  Linkin Park                  71                 86
#
#       year
# 4206  2002
# 4432  2004
# 4478  2004
# 4737  2007
# 4854  2008
# 4960  2009
# 5299  2012

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import sys

def create_similarity():
    data = pd.read_csv('main_song.csv')
    # creating a count matrix or count vectorizer matrix(all tf-idf stuff)
    cv = CountVectorizer()
    count_matrix = cv.fit_transform(data['Artist'])
    # creating a similarity score matrix
    similarity = cosine_similarity(count_matrix)
    return data,similarity

def rcmd(m):
    m = m.lower()
    try:
        data.head()
        similarity.shape
    except:
        data, similarity = create_similarity()
    if m not in data['Title'].unique():
        return('Sorry! The song you requested is not in our database. Please check the spelling or try with some other movies')
    else:
        i = data.loc[data['Title']==m].index[0]


        lst = list(enumerate(similarity[i]))
        lst = sorted(lst, key = lambda x:x[1] ,reverse=True)
        lst = lst[1:11] # excluding first item since it is the requested movie itself
        l = []

        for i in range(len(lst)):
            a = lst[i][0]
            l.append(data['Title'][a])
        return l

# %%
len(rcmd('burn it down'))
rcmd('burn it down')
# Out:
# ['numb',
#  'breaking the habit',
#  'what i’ve done',
#  'shadow of the day',
#  'new divide',
#  'burn it down',
#  'numb/encore',
#  'theme from “a summer place”',
#  'he’ll have to go',
#  'cathy’s clown']

# %%
data4=pd.read_csv('bollysong.csv', encoding = 'unicode_escape') #essential main dataset

# %%
data4 # recommendation will be based on these features only
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                         Singer/Artists  \
# 0                  Kumar Sanu, Mika Singh, Neha Kakkar
# 1                             Neha Kakkar, Tony Kakkar
# 2                                        Ranveer Singh
# 3                Jyotica Tangri, Shaan, Subhro Ganguly
# 4     Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
# ...                                                ...
# 2415                                            Mukesh
# 2416                                   Lata Mangeshkar
# 2417                    Lata Mangeshkar, Suresh Wadkar
# 2418                                       Jagjit Kaur
# 2419                                       Asha Bhosle
#
#                        Genre                Album/Movie User-Rating
# 0             BollywoodDance                     Simmba      8.8/10
# 1     BollywoodDanceRomantic                Luka Chuppi      9.0/10
# 2             BollywoodDance                  Gully Boy      9.7/10
# 3             BollywoodDance              Total Dhamaal      9.1/10
# 4          BollywoodRomantic                     Simmba      9.2/10
# ...                      ...                        ...         ...
# 2415          BollywoodDance                    Sasural      10-Oct
# 2416          BollywoodDance  Jab Pyar Kisi Se Hota Hai      10-Oct
# 2417          BollywoodDance                      Lamhe      10-Oct
# 2418          BollywoodDance          Shola Aur Shabnam      10-Oct
# 2419          BollywoodDance          Shola Aur Shabnam      6.6/10
#
# [2420 rows x 5 columns]

# %%
data4["Song-Name"]
# Out:
# 0                              Aankh Marey
# 1                                Coca Cola
# 2                         Apna Time Aayega
# 3                                   Mungda
# 4                                 Tere Bin
#                        ...
# 2415                Jana Tumhare Pyar Mein
# 2416               Tum Jaise Bigde Babu Se
# 2417                O Yaad Nahi Bhool Gaya
# 2418     Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419    Mummy Aur Daddy Mein Ladai Ho Gayi
# Name: Song-Name, Length: 2420, dtype: object

# %%
data4.head(10)
# Out:
#                          Song-Name  \
# 0                      Aankh Marey
# 1                        Coca Cola
# 2                 Apna Time Aayega
# 3                           Mungda
# 4                         Tere Bin
# 5                        Gali Gali
# 6                    Chamma Chamma
# 7                  Mere Gully Mein
# 8                         Kamariya
# 9  Ek Ladki Ko Dekha Toh Aisa Laga
#
#                                      Singer/Artists                   Genre  \
# 0               Kumar Sanu, Mika Singh, Neha Kakkar          BollywoodDance
# 1                          Neha Kakkar, Tony Kakkar  BollywoodDanceRomantic
# 2                                     Ranveer Singh          BollywoodDance
# 3             Jyotica Tangri, Shaan, Subhro Ganguly          BollywoodDance
# 4  Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi       BollywoodRomantic
# 5                                       Neha Kakkar          BollywoodDance
# 6                     Arun, Ikka, Neha Kakkar, Romy          BollywoodDance
# 7                                     Ranveer Singh          BollywoodDance
# 8                                     Darshan Raval          BollywoodDance
# 9                       Darshan Raval, Rochak Kohli       BollywoodRomantic
#
#                        Album/Movie User-Rating
# 0                           Simmba      8.8/10
# 1                      Luka Chuppi      9.0/10
# 2                        Gully Boy      9.7/10
# 3                    Total Dhamaal      9.1/10
# 4                           Simmba      9.2/10
# 5                              KGF      9.1/10
# 6                    Fraud Saiyaan      9.2/10
# 7                        Gully Boy      9.5/10
# 8                           Mitron      9.2/10
# 9  Ek Ladki Ko Dekha Toh Aisa Laga      9.6/10

# %%
data4['Song-Name'] = data4['Song-Name'].replace(np.nan, 'unknown')
data4['Singer/Artists'] = data4['Singer/Artists'].replace(np.nan, 'unknown')
data4['Genre'] = data4['Genre'].replace(np.nan, 'unknown')
data4['Album/Movie'] = data4['Album/Movie'].replace(np.nan, 'unknown')
data4['User-Rating'] = data4['User-Rating'].replace(np.nan, 'unknown')

# %%
data4['Song-Name'] = data4['Song-Name'].str.lower()
data4['Singer/Artists'] = data4['Singer/Artists'].str.lower()
data4['Genre'] = data4['Genre'].str.lower()
data4['Album/Movie'] = data4['Album/Movie'].str.lower()

# %%
data4['comb'] = data4['Song-Name'] + ' ' + data4['Singer/Artists'] + ' ' + data4['Song-Name'] + ' ' + data4['Album/Movie'] + ' ' + data4['Genre']

# %%
data4['Song-Name'][0]
data4
# Out:
#                                Song-Name  \
# 0                            aankh marey
# 1                              coca cola
# 2                       apna time aayega
# 3                                 mungda
# 4                               tere bin
# ...                                  ...
# 2415              jana tumhare pyar mein
# 2416             tum jaise bigde babu se
# 2417              o yaad nahi bhool gaya
# 2418   ladi re ladi tujhse aankh jo ladi
# 2419  mummy aur daddy mein ladai ho gayi
#
#                                         Singer/Artists  \
# 0                  kumar sanu, mika singh, neha kakkar
# 1                             neha kakkar, tony kakkar
# 2                                        ranveer singh
# 3                jyotica tangri, shaan, subhro ganguly
# 4     asees kaur, rahat fateh ali khan, tanishk bagchi
# ...                                                ...
# 2415                                            mukesh
# 2416                                   lata mangeshkar
# 2417                    lata mangeshkar, suresh wadkar
# 2418                                       jagjit kaur
# 2419                                       asha bhosle
#
#                        Genre                Album/Movie User-Rating  \
# 0             bollywooddance                     simmba      8.8/10
# 1     bollywooddanceromantic                luka chuppi      9.0/10
# 2             bollywooddance                  gully boy      9.7/10
# 3             bollywooddance              total dhamaal      9.1/10
# 4          bollywoodromantic                     simmba      9.2/10
# ...                      ...                        ...         ...
# 2415          bollywooddance                    sasural      10-Oct
# 2416          bollywooddance  jab pyar kisi se hota hai      10-Oct
# 2417          bollywooddance                      lamhe      10-Oct
# 2418          bollywooddance          shola aur shabnam      10-Oct
# 2419          bollywooddance          shola aur shabnam      6.6/10
#
#                                                    comb
# 0     aankh marey kumar sanu, mika singh, neha kakka...
# 1     coca cola neha kakkar, tony kakkar coca cola l...
# 2     apna time aayega ranveer singh apna time aayeg...
# 3     mungda jyotica tangri, shaan, subhro ganguly m...
# 4     tere bin asees kaur, rahat fateh ali khan, tan...
# ...                                                 ...
# 2415  jana tumhare pyar mein mukesh jana tumhare pya...
# 2416  tum jaise bigde babu se lata mangeshkar tum ja...
# 2417  o yaad nahi bhool gaya lata mangeshkar, suresh...
# 2418  ladi re ladi tujhse aankh jo ladi jagjit kaur ...
# 2419  mummy aur daddy mein ladai ho gayi asha bhosle...
#
# [2420 rows x 6 columns]

# %%
data4.to_csv('song-data-preprocessed1.csv',index=False)
